# %%
import numpy as np
import pandas as pd
from __future__ import print_function

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.svm import SVC

# %%
dfb=pd.read_csv("wbc.csv")

# %%
dfb.head()
# Out:
#    clump_thickness  cell_size  cell_shape  marginal_adhesion  \
# 0                5          1           1                  1
# 1                5          4           4                  5
# 2                3          1           1                  1
# 3                6          8           8                  1
# 4                4          1           1                  3
#
#    epitelial_cellsize bare_nuclei  bland_chromatin  normal_nucleoli  mitoses  \
# 0                   2           1                3                1        1
# 1                   7          10                3                2        1
# 2                   2           2                3                1        1
# 3                   3           4                3                7        1
# 4                   2           1                3                1        1
#
#    jenis
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2

# %%
dfb=dfb[dfb.bare_nuclei!='?']

# %%
dfb
# Out:
#      clump_thickness  cell_size  cell_shape  marginal_adhesion  \
# 0                  5          1           1                  1
# 1                  5          4           4                  5
# 2                  3          1           1                  1
# 3                  6          8           8                  1
# 4                  4          1           1                  3
# 5                  8         10          10                  8
# 6                  1          1           1                  1
# 7                  2          1           2                  1
# 8                  2          1           1                  1
# 9                  4          2           1                  1
# 10                 1          1           1                  1
# 11                 2          1           1                  1
# 12                 5          3           3                  3
# 13                 1          1           1                  1
# 14                 8          7           5                 10
# 15                 7          4           6                  4
# 16                 4          1           1                  1
# 17                 4          1           1                  1
# 18                10          7           7                  6
# 19                 6          1           1                  1
# 20                 7          3           2                 10
# 21                10          5           5                  3
# 22                 3          1           1                  1
# 24                 1          1           1                  1
# 25                 5          2           3                  4
# 26                 3          2           1                  1
# 27                 5          1           1                  1
# 28                 2          1           1                  1
# 29                 1          1           3                  1
# 30                 3          1           1                  1
# ..               ...        ...         ...                ...
# 669                5         10          10                  8
# 670                3         10           7                  8
# 671                3          2           1                  2
# 672                2          1           1                  1
# 673                5          3           2                  1
# 674                1          1           1                  1
# 675                4          1           4                  1
# 676                1          1           2                  1
# 677                5          1           1                  1
# 678                1          1           1                  1
# 679                2          1           1                  1
# 680               10         10          10                 10
# 681                5         10          10                 10
# 682                5          1           1                  1
# 683                1          1           1                  1
# 684                1          1           1                  1
# 685                1          1           1                  1
# 686                1          1           1                  1
# 687                3          1           1                  1
# 688                4          1           1                  1
# 689                1          1           1                  1
# 690                1          1           1                  3
# 691                5         10          10                  5
# 692                3          1           1                  1
# 693                3          1           1                  1
# 694                3          1           1                  1
# 695                2          1           1                  1
# 696                5         10          10                  3
# 697                4          8           6                  4
# 698                4          8           8                  5
#
#      epitelial_cellsize bare_nuclei  bland_chromatin  normal_nucleoli  \
# 0                     2           1                3                1
# 1                     7          10                3                2
# 2                     2           2                3                1
# 3                     3           4                3                7
# 4                     2           1                3                1
# 5                     7          10                9                7
# 6                     2          10                3                1
# 7                     2           1                3                1
# 8                     2           1                1                1
# 9                     2           1                2                1
# 10                    1           1                3                1
# 11                    2           1                2                1
# 12                    2           3                4                4
# 13                    2           3                3                1
# 14                    7           9                5                5
# 15                    6           1                4                3
# 16                    2           1                2                1
# 17                    2           1                3                1
# 18                    4          10                4                1
# 19                    2           1                3                1
# 20                    5          10                5                4
# 21                    6           7                7               10
# 22                    2           1                2                1
# 24                    2           1                3                1
# 25                    2           7                3                6
# 26                    1           1                2                1
# 27                    2           1                2                1
# 28                    2           1                2                1
# 29                    2           1                1                1
# 30                    1           1                2                1
# ..                  ...         ...              ...              ...
# 669                   5           5                7               10
# 670                   5           8                7                4
# 671                   2           1                3                1
# 672                   2           1                3                1
# 673                   3           1                1                1
# 674                   2           1                2                1
# 675                   2           1                1                1
# 676                   2           1                2                1
# 677                   2           1                1                1
# 678                   2           1                1                1
# 679                   2           1                1                1
# 680                   5          10               10               10
# 681                   4          10                5                6
# 682                   2           1                3                2
# 683                   2           1                1                1
# 684                   2           1                1                1
# 685                   2           1                1                1
# 686                   2           1                1                1
# 687                   2           1                2                3
# 688                   2           1                1                1
# 689                   2           1                1                1
# 690                   2           1                1                1
# 691                   4           5                4                4
# 692                   2           1                1                1
# 693                   2           1                2                1
# 694                   3           2                1                1
# 695                   2           1                1                1
# 696                   7           3                8               10
# 697                   3           4               10                6
# 698                   4           5               10                4
#
#      mitoses  jenis
# 0          1      2
# 1          1      2
# 2          1      2
# 3          1      2
# 4          1      2
# 5          1      4
# 6          1      2
# 7          1      2
# 8          5      2
# 9          1      2
# 10         1      2
# 11         1      2
# 12         1      4
# 13         1      2
# 14         4      4
# 15         1      4
# 16         1      2
# 17         1      2
# 18         2      4
# 19         1      2
# 20         4      4
# 21         1      4
# 22         1      2
# 24         1      2
# 25         1      4
# 26         1      2
# 27         1      2
# 28         1      2
# 29         1      2
# 30         1      2
# ..       ...    ...
# 669        1      4
# 670        1      4
# 671        1      2
# 672        1      2
# 673        1      2
# 674        1      2
# 675        1      2
# 676        1      2
# 677        1      2
# 678        1      2
# 679        1      2
# 680        7      4
# 681        3      4
# 682        1      2
# 683        1      2
# 684        1      2
# 685        1      2
# 686        1      2
# 687        1      2
# 688        1      2
# 689        8      2
# 690        1      2
# 691        1      4
# 692        1      2
# 693        2      2
# 694        1      2
# 695        1      2
# 696        2      4
# 697        1      4
# 698        1      4
#
# [683 rows x 10 columns]

# %%
dfb.describe()
# Out:
#        clump_thickness   cell_size  cell_shape  marginal_adhesion  \
# count       683.000000  683.000000  683.000000         683.000000
# mean          4.442167    3.150805    3.215227           2.830161
# std           2.820761    3.065145    2.988581           2.864562
# min           1.000000    1.000000    1.000000           1.000000
# 25%           2.000000    1.000000    1.000000           1.000000
# 50%           4.000000    1.000000    1.000000           1.000000
# 75%           6.000000    5.000000    5.000000           4.000000
# max          10.000000   10.000000   10.000000          10.000000
#
#        epitelial_cellsize  bland_chromatin  normal_nucleoli     mitoses  \
# count          683.000000       683.000000       683.000000  683.000000
# mean             3.234261         3.445095         2.869693    1.603221
# std              2.223085         2.449697         3.052666    1.732674
# min              1.000000         1.000000         1.000000    1.000000
# 25%              2.000000         2.000000         1.000000    1.000000
# 50%              2.000000         3.000000         1.000000    1.000000
# 75%              4.000000         5.000000         4.000000    1.000000
# max             10.000000        10.000000        10.000000   10.000000
#
#             jenis
# count  683.000000
# mean     2.699854
# std      0.954592
# min      2.000000
# 25%      2.000000
# 50%      2.000000
# 75%      4.000000
# max      4.000000

# %%
dfb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 683 entries, 0 to 698
# Data columns (total 10 columns):
# clump_thickness       683 non-null int64
# cell_size             683 non-null int64
# cell_shape            683 non-null int64
# marginal_adhesion     683 non-null int64
# epitelial_cellsize    683 non-null int64
# bare_nuclei           683 non-null object
# bland_chromatin       683 non-null int64
# normal_nucleoli       683 non-null int64
# mitoses               683 non-null int64
# jenis                 683 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 58.7+ KB

# %%
dfb=dfb.reset_index()

# %%
dfb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683 entries, 0 to 682
# Data columns (total 11 columns):
# index                 683 non-null int64
# clump_thickness       683 non-null int64
# cell_size             683 non-null int64
# cell_shape            683 non-null int64
# marginal_adhesion     683 non-null int64
# epitelial_cellsize    683 non-null int64
# bare_nuclei           683 non-null object
# bland_chromatin       683 non-null int64
# normal_nucleoli       683 non-null int64
# mitoses               683 non-null int64
# jenis                 683 non-null int64
# dtypes: int64(10), object(1)
# memory usage: 58.8+ KB

# %%
dfb.describe()
# Out:
#             index  clump_thickness   cell_size  cell_shape  marginal_adhesion  \
# count  683.000000       683.000000  683.000000  683.000000         683.000000
# mean   351.355783         4.442167    3.150805    3.215227           2.830161
# std    202.563927         2.820761    3.065145    2.988581           2.864562
# min      0.000000         1.000000    1.000000    1.000000           1.000000
# 25%    176.500000         2.000000    1.000000    1.000000           1.000000
# 50%    355.000000         4.000000    1.000000    1.000000           1.000000
# 75%    526.500000         6.000000    5.000000    5.000000           4.000000
# max    698.000000        10.000000   10.000000   10.000000          10.000000
#
#        epitelial_cellsize  bland_chromatin  normal_nucleoli     mitoses  \
# count          683.000000       683.000000       683.000000  683.000000
# mean             3.234261         3.445095         2.869693    1.603221
# std              2.223085         2.449697         3.052666    1.732674
# min              1.000000         1.000000         1.000000    1.000000
# 25%              2.000000         2.000000         1.000000    1.000000
# 50%              2.000000         3.000000         1.000000    1.000000
# 75%              4.000000         5.000000         4.000000    1.000000
# max             10.000000        10.000000        10.000000   10.000000
#
#             jenis
# count  683.000000
# mean     2.699854
# std      0.954592
# min      2.000000
# 25%      2.000000
# 50%      2.000000
# 75%      4.000000
# max      4.000000

# %%
dfb['bare_nuclei']=dfb['bare_nuclei'].astype(object).astype(int)

# %%
dfb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683 entries, 0 to 682
# Data columns (total 11 columns):
# index                 683 non-null int64
# clump_thickness       683 non-null int64
# cell_size             683 non-null int64
# cell_shape            683 non-null int64
# marginal_adhesion     683 non-null int64
# epitelial_cellsize    683 non-null int64
# bare_nuclei           683 non-null int32
# bland_chromatin       683 non-null int64
# normal_nucleoli       683 non-null int64
# mitoses               683 non-null int64
# jenis                 683 non-null int64
# dtypes: int32(1), int64(10)
# memory usage: 56.1 KB

# %%
dfb[dfb.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [index, clump_thickness, cell_size, cell_shape, marginal_adhesion, epitelial_cellsize, bare_nuclei, bland_chromatin, normal_nucleoli, mitoses, jenis]
# Index: []

# %%
dfb.describe()
# Out:
#             index  clump_thickness   cell_size  cell_shape  marginal_adhesion  \
# count  683.000000       683.000000  683.000000  683.000000         683.000000
# mean   351.355783         4.442167    3.150805    3.215227           2.830161
# std    202.563927         2.820761    3.065145    2.988581           2.864562
# min      0.000000         1.000000    1.000000    1.000000           1.000000
# 25%    176.500000         2.000000    1.000000    1.000000           1.000000
# 50%    355.000000         4.000000    1.000000    1.000000           1.000000
# 75%    526.500000         6.000000    5.000000    5.000000           4.000000
# max    698.000000        10.000000   10.000000   10.000000          10.000000
#
#        epitelial_cellsize  bare_nuclei  bland_chromatin  normal_nucleoli  \
# count          683.000000   683.000000       683.000000       683.000000
# mean             3.234261     3.544656         3.445095         2.869693
# std              2.223085     3.643857         2.449697         3.052666
# min              1.000000     1.000000         1.000000         1.000000
# 25%              2.000000     1.000000         2.000000         1.000000
# 50%              2.000000     1.000000         3.000000         1.000000
# 75%              4.000000     6.000000         5.000000         4.000000
# max             10.000000    10.000000        10.000000        10.000000
#
#           mitoses       jenis
# count  683.000000  683.000000
# mean     1.603221    2.699854
# std      1.732674    0.954592
# min      1.000000    2.000000
# 25%      1.000000    2.000000
# 50%      1.000000    2.000000
# 75%      1.000000    4.000000
# max     10.000000    4.000000

# %%
print(__doc__)

# Loading the Digits dataset
#digits = datasets.load_digits()

# To apply an classifier on this data, we need to flatten the image, to
# turn the data in a (samples, feature) matrix:
n_samples = len(dfb)
X = dfb.reshape((n_samples, -1))
y = dfb.jenis

# Split the dataset in two equal parts
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=0)

# Set the parameters by cross-validation
tuned_parameters = [{'kernel': ['rbf'], 'gamma': [2e1,2e3],
                     'C': [ 2e1,2e3]},]

scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(SVC(C=1), tuned_parameters, cv=5,
                       scoring='%s_macro' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# Automatically created module for IPython interactive environment
# # Tuning hyper-parameters for precision
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Best parameters set found on development set:
#
# {'C': 20.0, 'gamma': 20.0, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.330 (+/-0.002) for {'C': 20.0, 'gamma': 20.0, 'kernel': 'rbf'}
# 0.330 (+/-0.002) for {'C': 20.0, 'gamma': 2000.0, 'kernel': 'rbf'}
# 0.330 (+/-0.002) for {'C': 2000.0, 'gamma': 20.0, 'kernel': 'rbf'}
# 0.330 (+/-0.002) for {'C': 2000.0, 'gamma': 2000.0, 'kernel': 'rbf'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           2       0.63      1.00      0.77       142
#           4       0.00      0.00      0.00        84
#
# avg / total       0.39      0.63      0.48       226
#
#
# # Tuning hyper-parameters for recall
#
# Best parameters set found on development set:
#
# {'C': 20.0, 'gamma': 20.0, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.500 (+/-0.000) for {'C': 20.0, 'gamma': 20.0, 'kernel': 'rbf'}
# 0.500 (+/-0.000) for {'C': 20.0, 'gamma': 2000.0, 'kernel': 'rbf'}
# 0.500 (+/-0.000) for {'C': 2000.0, 'gamma': 20.0, 'kernel': 'rbf'}
# 0.500 (+/-0.000) for {'C': 2000.0, 'gamma': 2000.0, 'kernel': 'rbf'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           2       0.63      1.00      0.77       142
#           4       0.00      0.00      0.00        84
#
# avg / total       0.39      0.63      0.48       226
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
print(__doc__)

# Loading the Digits dataset
#digits = datasets.load_digits()

# To apply an classifier on this data, we need to flatten the image, to
# turn the data in a (samples, feature) matrix:
n_samples = len(dfb)
X = dfb.drop([dfb.columns[-1]], axis=1)
y = dfb.jenis

# Split the dataset in two equal parts
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=0)

# Set the parameters by cross-validation
tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4],
                     'C': [1e-3, 1e-4]},]

scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(SVC(C=1), tuned_parameters, cv=5,
                       scoring='%s_macro' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# Automatically created module for IPython interactive environment
# # Tuning hyper-parameters for precision
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Best parameters set found on development set:
#
# {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.330 (+/-0.002) for {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.330 (+/-0.002) for {'C': 0.001, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.330 (+/-0.002) for {'C': 0.0001, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.330 (+/-0.002) for {'C': 0.0001, 'gamma': 0.0001, 'kernel': 'rbf'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           2       0.63      1.00      0.77       142
#           4       0.00      0.00      0.00        84
#
# avg / total       0.39      0.63      0.48       226
#
#
# # Tuning hyper-parameters for recall
#
# Best parameters set found on development set:
#
# {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.500 (+/-0.000) for {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.500 (+/-0.000) for {'C': 0.001, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.500 (+/-0.000) for {'C': 0.0001, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.500 (+/-0.000) for {'C': 0.0001, 'gamma': 0.0001, 'kernel': 'rbf'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           2       0.63      1.00      0.77       142
#           4       0.00      0.00      0.00        84
#
# avg / total       0.39      0.63      0.48       226
# C:\Users\Annisa\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
