# %%
from scipy.stats import norm, poisson
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# c:\users\annisa\anaconda3\envs\py35\lib\site-packages\IPython\html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("wbc.csv")

# %%
df.head()
# Out:
#    clump_thickness  cell_size  cell_shape  marginal_adhesion  \
# 0                5          1           1                  1
# 1                5          4           4                  5
# 2                3          1           1                  1
# 3                6          8           8                  1
# 4                4          1           1                  3
#
#    epitelial_cellsize bare_nuclei  bland_chromatin  normal_nucleoli  mitoses  \
# 0                   2           1                3                1        1
# 1                   7          10                3                2        1
# 2                   2           2                3                1        1
# 3                   3           4                3                7        1
# 4                   2           1                3                1        1
#
#    jenis
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2

# %%
df = df.replace('?',np.nan)

# %%
df[df.isnull().any(axis=1)]
# Out:
#      clump_thickness  cell_size  cell_shape  marginal_adhesion  \
# 23                 8          4           5                  1
# 40                 6          6           6                  9
# 139                1          1           1                  1
# 145                1          1           3                  1
# 158                1          1           2                  1
# 164                5          1           1                  1
# 235                3          1           4                  1
# 249                3          1           1                  1
# 275                3          1           3                  1
# 292                8          8           8                  1
# 294                1          1           1                  1
# 297                5          4           3                  1
# 315                4          6           5                  6
# 321                3          1           1                  1
# ...

# %%
df.bare_nuclei.value_counts()
# Out:
# 1     402
# 10    132
# 5      30
# 2      30
# 3      28
# 8      21
# 4      19
# 9       9
# 7       8
# 6       4
# Name: bare_nuclei, dtype: int64

# %%
df['bare_nuclei'] = pd.to_numeric(df.bare_nuclei.fillna(df.bare_nuclei.median()))

# %%
df.bare_nuclei.value_counts()
# Out:
# 1.0     418
# 10.0    132
# 5.0      30
# 2.0      30
# 3.0      28
# 8.0      21
# 4.0      19
# 9.0       9
# 7.0       8
# 6.0       4
# Name: bare_nuclei, dtype: int64

# %%
df['jenis']=df['jenis'].map({2:0,4:1})

# %%
df0 = df[df.jenis == 0]
df1 = df[df.jenis == 1]
fig, ax = plt.subplots(1,2, sharey=True, figsize=(15,5))
ax[0].scatter(df0.clump_thickness, df0.mitoses, c='r')
ax[1].scatter(df1.clump_thickness, df1.mitoses, c='b')
plt.show()

# %%
df0 = df[df.jenis == 0]
df1 = df[df.jenis == 1]
fig, ax = plt.subplots(1,2, sharey=True, figsize=(15,5))
ax[0].scatter(df0.cell_size, df0.mitoses, c='r')
ax[1].scatter(df1.cell_size, df1.mitoses, c='b')
plt.show()

# %%
df0 = df[df.jenis == 0]
df1 = df[df.jenis == 1]
fig, ax = plt.subplots(1,2, sharey=True, figsize=(15,5))
ax[0].scatter(df0.cell_shape, df0.mitoses, c='r')
ax[1].scatter(df1.cell_shape, df1.mitoses, c='b')
plt.show()

# %%
df0 = df[df.jenis == 0]
df1 = df[df.jenis == 1]
fig, ax = plt.subplots(1,2, sharey=True, figsize=(15,5))
ax[0].scatter(df0.bare_nuclei, df0.mitoses, c='r')
ax[1].scatter(df1.bare_nuclei, df1.mitoses, c='b')
plt.show()

# %%
df0 = df[df.jenis == 0]
df1 = df[df.jenis == 1]
fig, ax = plt.subplots(1,2, sharey=True, figsize=(15,5))
ax[0].scatter(df0.marginal_adhesion, df0.mitoses, c='r')
ax[1].scatter(df1.marginal_adhesion, df1.mitoses, c='b')
plt.show()

# %%
df0 = df[df.jenis == 0]
df1 = df[df.jenis == 1]
fig, ax = plt.subplots(1,2, sharey=True, figsize=(15,5))
ax[0].scatter(df0.epitelial_cellsize, df0.mitoses, c='r')
ax[1].scatter(df1.epitelial_cellsize, df1.mitoses, c='b')
plt.show()

# %%
df0 = df[df.jenis == 0]
df1 = df[df.jenis == 1]
fig, ax = plt.subplots(1,2, sharey=True, figsize=(15,5))
ax[0].scatter(df0.bland_chromatin, df0.mitoses, c='r')
ax[1].scatter(df1.bland_chromatin, df1.mitoses, c='b')
plt.show()

# %%
df0 = df[df.jenis == 0]
df1 = df[df.jenis == 1]
fig, ax = plt.subplots(1,2, sharey=True, figsize=(15,5))
ax[0].scatter(df0.normal_nucleoli, df0.mitoses, c='r')
ax[1].scatter(df1.normal_nucleoli, df1.mitoses, c='b')
plt.show()

# %%
df0 = df[df.jenis == 0]
df1 = df[df.jenis == 1]
fig, ax = plt.subplots(1,2, sharey=True, figsize=(15,5))
ax[0].scatter(df0.mitoses, df0.mitoses, c='r')
ax[1].scatter(df1.mitoses, df1.mitoses, c='b')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
from sklearn.naive_bayes import GaussianNB, MultinomialNB

# %%
X = df.drop([df.columns[-1]], axis=1)
y = df.jenis
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1337)

# %%
import pylab

# %%
figure = plt.figure(figsize=(9,5))
plt.hist([df[df['jenis']==0]['clump_thickness'],df[df['jenis']==1]['clump_thickness']], stacked=True, color = ['g','r'],
         bins = 10,label = ['Benign','Malignant'])
plt.axis([0, 10, 0, 150])
plt.xlabel('Clump Thickness',fontsize=14)
plt.ylabel('Jumlah Penderita',fontsize=14)
plt.rc('xtick',labelsize=14)
plt.rc('ytick',labelsize=14)
plt.legend(prop={'size':14})

# %%
figure = plt.figure(figsize=(9,5))
plt.hist([df[df['jenis']==0]['cell_size'],df[df['jenis']==1]['cell_size']], stacked=True, color = ['g','r'],
         bins = 10,label = ['Benign','Malignant'])
plt.xlabel('Uniformity of Cell Size',fontsize=14)
plt.ylabel('Jumlah Penderita',fontsize=14)
plt.rc('xtick',labelsize=14)
plt.rc('ytick',labelsize=14)
plt.legend(prop={'size':14})

# %%
figure = plt.figure(figsize=(9,5))
plt.hist([df[df['jenis']==0]['cell_shape'],df[df['jenis']==1]['cell_shape']], stacked=True, color = ['g','r'],
         bins = 10,label = ['Benign','Malignant'])
plt.xlabel('Uniformity of Cell Shape',fontsize=14)
plt.ylabel('Jumlah Penderita',fontsize=14)
plt.rc('xtick',labelsize=14)
plt.rc('ytick',labelsize=14)
plt.legend(prop={'size':14})

# %%
figure = plt.figure(figsize=(9,5))
plt.hist([df[df['jenis']==0]['marginal_adhesion'],df[df['jenis']==1]['marginal_adhesion']], stacked=True, color = ['g','r'],
         bins = 10,label = ['Benign','Malignant'])
plt.xlabel('Marginal Adhesion',fontsize=14)
plt.ylabel('Jumlah Penderita',fontsize=14)
plt.rc('xtick',labelsize=14)
plt.rc('ytick',labelsize=14)
plt.legend(prop={'size':14})

# %%
figure = plt.figure(figsize=(9,5))
plt.hist([df[df['jenis']==0]['epitelial_cellsize'],df[df['jenis']==1]['epitelial_cellsize']], stacked=True, color = ['g','r'],
         bins = 10,label = ['Benign','Malignant'])
plt.xlabel('Single Epithelial Cell Size',fontsize=14)
plt.ylabel('Jumlah Penderita',fontsize=14)
plt.rc('xtick',labelsize=14)
plt.rc('ytick',labelsize=14)
plt.legend(prop={'size':14})

# %%
figure = plt.figure(figsize=(9,5))
plt.hist([df[df['jenis']==0]['bare_nuclei'],df[df['jenis']==1]['bare_nuclei']], stacked=True, color = ['g','r'],
         bins = 10,label = ['Benign','Malignant'])
plt.xlabel('Bare Nuclei',fontsize=14)
plt.ylabel('Jumlah Penderita',fontsize=14)
plt.rc('xtick',labelsize=14)
plt.rc('ytick',labelsize=14)
plt.legend(prop={'size':14})

# %%
figure = plt.figure(figsize=(9,5))
plt.hist([df[df['jenis']==0]['bland_chromatin'],df[df['jenis']==1]['bland_chromatin']], stacked=True, color = ['g','r'],
         bins = 10,label = ['Benign','Malignant'])
plt.xlabel('Bland Chromatin',fontsize=14)
plt.ylabel('Jumlah Penderita',fontsize=14)
plt.rc('xtick',labelsize=14)
plt.rc('ytick',labelsize=14)
plt.legend(prop={'size':14})

# %%
figure = plt.figure(figsize=(9,5))
plt.hist([df[df['jenis']==0]['normal_nucleoli'],df[df['jenis']==1]['normal_nucleoli']], stacked=True, color = ['g','r'],
         bins = 10,label = ['Benign','Malignant'])
plt.xlabel('Normal Nucleoli',fontsize=14)
plt.ylabel('Jumlah Penderita',fontsize=14)
plt.rc('xtick',labelsize=14)
plt.rc('ytick',labelsize=14)
plt.legend(prop={'size':14})

# %%
figure = plt.figure(figsize=(9,5))
plt.hist([df[df['jenis']==0]['mitoses'],df[df['jenis']==1]['mitoses']], stacked=True, color = ['g','r'],
         bins = 10,label = ['Benign','Malignant'])
plt.xlabel('Mitoses',fontsize=14)
plt.ylabel('Jumlah Penderita',fontsize=14)
plt.rc('xtick',labelsize=14)
plt.rc('ytick',labelsize=14)
plt.legend(prop={'size':14})

# %%
names = np.arange(0,10)

# %%
figure = plt.figure(figsize=(9,5))
plt.hist([df[df['jenis']==0]['mitoses'],df[df['jenis']==1]['mitoses']], stacked=True, color = ['g','r'],
         bins = 10,label = ['Benign','Malignant'])
plt.xlabel('Mitoses',fontsize=14)
plt.ylabel('Jumlah Penderita',fontsize=14)
plt.rc('xtick',labelsize=14)
plt.rc('ytick',labelsize=14)
plt.legend(prop={'size':14})

# %%
import seaborn as sns
corr = df.corr() # .corr is used for find corelation
sns.set(font_scale=1.8)
plt.figure(figsize=(14,14))
xticks=corr.columns.values
yticks=corr.columns.values
g = sns.heatmap(corr, cbar = True,  square = True, annot=True, fmt= '.2f',annot_kws={'size': 16},
           xticklabels= xticks, yticklabels= yticks,
           cmap= 'Blues')
plt.yticks(rotation=0)
#plt.xticks(rotation=90)
g.xaxis.tick_top()
g.set_xticklabels(xticks, rotation=90, ha='center')
#plt.tick_params(top='on', labeltop='on', labelright='off', labelbottom='off')

plt.show()

# %%
import seaborn as sns
corr = df.corr() # .corr is used for find corelation
sns.set(font_scale=1.8)
plt.figure(figsize=(14,14))
xticks=corr.columns.values
yticks=corr.columns.values
g = sns.heatmap(corr, cbar = True,  square = True, annot=True, fmt= '.2f',annot_kws={'size': 16},
           xticklabels= xticks, yticklabels= yticks,
           cmap= 'OrRd')
plt.yticks(rotation=0)
#plt.xticks(rotation=90)
g.xaxis.tick_top()
g.set_xticklabels(xticks, rotation=90, ha='center')
#plt.tick_params(top='on', labeltop='on', labelright='off', labelbottom='off')

plt.show()
